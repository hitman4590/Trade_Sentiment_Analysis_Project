# %%
import pandas as pd

trader_df = pd.read_csv('historical_data.csv')
sentiment_df = pd.read_csv('fear_greed_index.csv')

trader_df.columns = trader_df.columns.str.lower().str.replace(' ', '_')
sentiment_df.columns = sentiment_df.columns.str.lower().str.replace(' ', '_')

trader_df['timestamp'] = pd.to_datetime(trader_df['timestamp'], unit='ms')
sentiment_df['date'] = pd.to_datetime(sentiment_df['date'])

trader_df['date_only'] = trader_df['timestamp'].dt.date
trader_df['date_only'] = pd.to_datetime(trader_df['date_only'])

merged_df = pd.merge(trader_df, sentiment_df, left_on='date_only', right_on='date', how='left')

print("\n--- First 5 Rows of Merged DataFrame ---")
print(merged_df.head())

print("\n--- DataFrame Info ---")
merged_df.info()
# Out:
# --- First 5 Rows of Merged DataFrame ---
#                                       account  coin  execution_price  \
# 0  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9769
# 1  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9800
# 2  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9855
# 3  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9874
# 4  0xae5eacaf9c6b9111fd53034a602c192a04e082ed  @107           7.9894
#
#    size_tokens  size_usd side     timestamp_ist  start_position direction  \
# 0       986.87   7872.16  BUY  02-12-2024 22:50        0.000000       Buy
# 1        16.00    127.68  BUY  02-12-2024 22:50      986.524596       Buy
# 2       144.09   1150.63  BUY  02-12-2024 22:50     1002.518996       Buy
# 3       142.98   1142.04  BUY  02-12-2024 22:50     1146.558564       Buy
# 4         8.73     69.75  BUY  02-12-2024 22:50     1289.488521       Buy
#
#    closed_pnl  ...     order_id  crossed       fee      trade_id  \
# 0         0.0  ...  52017706630     True  0.345404  8.950000e+14
# 1         0.0  ...  52017706630     True  0.005600  4.430000e+14
# 2         0.0  ...  52017706630     True  0.050431  6.600000e+14
# 3         0.0  ...  52017706630     True  0.050043  1.080000e+15
# 4         0.0  ...  52017706630     True  0.003055  1.050000e+15
#
#           timestamp_x  date_only   timestamp_y  value  classification  \
# 0 2024-10-27 03:33:20 2024-10-27  1.730007e+09   74.0           Greed
# 1 2024-10-27 03:33:20 2024-10-27  1.730007e+09   74.0           Greed
# 2 2024-10-27 03:33:20 2024-10-27  1.730007e+09   74.0           Greed
# 3 2024-10-27 03:33:20 2024-10-27  1.730007e+09   74.0           Greed
# 4 2024-10-27 03:33:20 2024-10-27  1.730007e+09   74.0           Greed
#
#         date
# 0 2024-10-27
# 1 2024-10-27
# 2 2024-10-27
# 3 2024-10-27
# 4 2024-10-27
#
# [5 rows x 21 columns]
#
# --- DataFrame Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211224 entries, 0 to 211223
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   account           211224 non-null  object
#  1   coin              211224 non-null  object
#  2   execution_price   211224 non-null  float64
#  3   size_tokens       211224 non-null  float64
#  4   size_usd          211224 non-null  float64
#  5   side              211224 non-null  object
#  6   timestamp_ist     211224 non-null  object
#  7   start_position    211224 non-null  float64
#  8   direction         211224 non-null  object
#  9   closed_pnl        211224 non-null  float64
#  10  transaction_hash  211224 non-null  object
#  11  order_id          211224 non-null  int64
#  12  crossed           211224 non-null  bool
#  13  fee               211224 non-null  float64
#  14  trade_id          211224 non-null  float64
#  15  timestamp_x       211224 non-null  datetime64[ns]
#  16  date_only         211224 non-null  datetime64[ns]
#  17  timestamp_y       184263 non-null  float64
#  18  value             184263 non-null  float64
#  19  classification    184263 non-null  object
#  20  date              184263 non-null  datetime64[ns]
# dtypes: bool(1), datetime64[ns](3), float64(9), int64(1), object(7)
# memory usage: 32.4+ MB
